# %%
import matplotlib.pyplot  as plt
import numpy as np

# %%
x = np.linspace(0, 2  * np.pi, 200)
y = np.sin(x)
fig, ax = plt.subplots()
ax.plot(x, y)
#plt.show()

# %% [markdown]
# Números generados uniformemente entre 0 y 1:
# Números generados con distribución normal (media=0, desviación estándar=1):

# %%
x = np.random.rand(100)
y =  np.random.rand(100)
plt.scatter(x, y)
plt.savefig('punto.png')

# %%
metros_cuadrados_min = 50
metros_cuadrados_max = 300
precios_min = 100
precios_max = 800
num_propiedades = 100 #NUmero de puntos
metros_cuadrados = np.random.uniform(metros_cuadrados_min, metros_cuadrados_max, num_propiedades)
precios = np.random.uniform(precios_min, precios_max, num_propiedades)
# metros_cuadrados = np.array([80, 100, 120, 140, 160, 180, 200])
# precios = np.array([200, 220, 250, 280, 300, 320, 350])

# Calcular la ecuación de la línea recta (y = mx + b)
m = 2 #Pendinte
b = 100 #Interseccion
y = m * metros_cuadrados + b

plt.scatter(metros_cuadrados, precios)
plt.plot(metros_cuadrados, y, color='red', label='Línea con Pendiente')

plt.xlabel('Metros Cuadrados (m^2)')
plt.ylabel('Precio (Miles de dólares)')
plt.title('Relación entre Metros Cuadrados y Precio de Propiedades')
plt.savefig('scatter_plot_propiedades.png')

# %%
num_puntos_grupo_1 = 50
num_puntos_grupo_2 = 50
# Generar puntos para el grupo 1
grupo_1_x = np.random.normal(0, 1, num_puntos_grupo_1)
grupo_1_y = np.random.normal(0, 1, num_puntos_grupo_1)
# Generar puntos para el grupo 2
grupo_2_x = np.random.normal(3, 1, num_puntos_grupo_2)
grupo_2_y = np.random.normal(3, 1, num_puntos_grupo_2)
# Crear el gráfico de dispersión (scatter plot) con puntos agrupados
plt.scatter(grupo_1_x, grupo_1_y, color='blue', label='Grupo 1')
plt.scatter(grupo_2_x, grupo_2_y, color='red', label='Grupo 2')

# Añadir etiquetas y título
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Gráfico de Puntos Agrupados')

# Mostrar la leyenda
# plt.legend()
# Mostrar el gráfico
plt.show()
